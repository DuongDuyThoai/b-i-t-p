# %% [markdown]
# <a href="https://colab.research.google.com/github/DuongDuyThoai/bai-tap-AI/blob/main/15_11_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install mtcnn
# !pip3 install opencv-contrib-python
from mtcnn import MTCNN
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mtcnn
#   Downloading mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 8.6 MB/s
# Requirement already satisfied: opencv-python>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from mtcnn) (4.6.0.66)
# Requirement already satisfied: keras>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from mtcnn) (2.9.0)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python>=4.1.0->mtcnn) (1.21.6)
# Installing collected packages: mtcnn
# Successfully installed mtcnn-0.1.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.7/dist-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-contrib-python) (1.21.6)

# %%
import matplotlib.pyplot as plt
url='/content/1.jpg'
pixels=plt.imread(url)
detector=MTCNN()
faces=detector.detect_faces(pixels)
for face in faces:
  print(face)
# Out:
# 1/1 [==============================] - 1s 938ms/step
# 1/1 [==============================] - 0s 254ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 51/51 [==============================] - 1s 11ms/step
# 9/9 [==============================] - 0s 39ms/step
# {'box': [411, 869, 35, 38], 'confidence': 0.9999997019767761, 'keypoints': {'left_eye': (421, 881), 'right_eye': (438, 880), 'nose': (430, 890), 'mouth_left': (422, 897), 'mouth_right': (438, 895)}}
# {'box': [309, 857, 36, 45], 'confidence': 0.9999987483024597, 'keypoints': {'left_eye': (319, 873), 'right_eye': (336, 875), 'nose': (326, 883), 'mouth_left': (318, 890), 'mouth_right': (333, 892)}}
# {'box': [77, 1053, 46, 59], 'confidence': 0.9999977946281433, 'keypoints': {'left_eye': (94, 1073), 'right_eye': (116, 1075), 'nose': (106, 1086), 'mouth_left': (93, 1098), 'mouth_right': (111, 1099)}}
# {'box': [1467, 831, 42, 50], 'confidence': 0.9999974966049194, 'keypoints': {'left_eye': (1476, 850), 'right_eye': (1495, 848), 'nose': (1485, 859), 'mouth_left': (1479, 869), 'mouth_right': (1496, 867)}}
# {'box': [757, 831, 31, 39], 'confidence': 0.9999951720237732, 'keypoints': {'left_eye': (766, 845), 'right_eye': (781, 845), 'nose': (774, 852), 'mouth_left': (768, 861), 'mouth_right': (780, 861)}}
# {'box': [1664, 1014, 43, 47], 'confidence': 0.9999950528144836, 'keypoints': {'left_eye': (1674, 1029), 'right_eye': (1695, 1028), 'nose': (1684, 1039), 'mouth_left': (1677, 1049), 'mouth_right': (1694, 1049)}}
# {'box': [973, 1053, 42, 54], 'confidence': 0.9999927878379822, 'keypoints': {'left_eye': (983, 1075), 'right_eye': (1002, 1073), 'nose': (992, 1086), 'mouth_left': (985, 1095), 'mouth_right': (1003, 1094)}}
# {'box': [340, 824, 33, 40], 'confidence': 0.9999896883964539, 'keypoints': {'left_eye': (351, 838), 'right_eye': (367, 842), 'nose': (357, 850), 'mouth_left': (348, 854), 'mouth_right': (363, 857)}}
# {'box': [1515, 1059, 46, 55], 'confidence': 0.9999862313270569, 'keypoints': {'left_eye': (1529, 1080), 'right_eye': (1551, 1082), 'nose': (1540, 1092), 'mouth_left': (1530, 1101), 'mouth_right': (1546, 1104)}}
# {'box': [1261, 836, 33, 43], 'confidence': 0.9999851584434509, 'keypoints': {'left_eye': (1267, 854), 'right_eye': (1282, 851), 'nose': (1273, 861), 'mouth_left': (1271, 870), 'mouth_right': (1283, 868)}}
# {'box': [705, 1048, 39, 48], 'confidence': 0.9999811053276062, 'keypoints': {'left_eye': (721, 1064), 'right_eye': (738, 1064), 'nose': (732, 1075), 'mouth_left': (722, 1085), 'mouth_right': (736, 1085)}}
# {'box': [1093, 858, 34, 45], 'confidence': 0.9999778866767883, 'keypoints': {'left_eye': (1103, 876), 'right_eye': (1119, 875), 'nose': (1112, 884), 'mouth_left': (1105, 893), 'mouth_right': (1118, 892)}}
# {'box': [805, 1030, 41, 57], 'confidence': 0.9999743103981018, 'keypoints': {'left_eye': (814, 1052), 'right_eye': (834, 1051), 'nose': (824, 1064), 'mouth_left': (816, 1073), 'mouth_right': (835, 1071)}}
# {'box': [1773, 1006, 54, 67], 'confidence': 0.9999710917472839, 'keypoints': {'left_eye': (1787, 1034), 'right_eye': (1812, 1031), 'nose': (1800, 1046), 'mouth_left': (1792, 1058), 'mouth_right': (1814, 1056)}}
# {'box': [1116, 1043, 41, 52], 'confidence': 0.9999663233757019, 'keypoints': {'left_eye': (1126, 1063), 'right_eye': (1146, 1061), 'nose': (1137, 1073), 'mouth_left': (1130, 1083), 'mouth_right': (1146, 1082)}}
# {'box': [1386, 1026, 44, 56], 'confidence': 0.9999637007713318, 'keypoints': {'left_eye': (1397, 1046), 'right_eye': (1419, 1046), 'nose': (1408, 1057), 'mouth_left': (1400, 1070), 'mouth_right': (1418, 1069)}}
# {'box': [477, 866, 34, 42], 'confidence': 0.9999592900276184, 'keypoints': {'left_eye': (486, 883), 'right_eye': (503, 883), 'nose': (494, 891), 'mouth_left': (486, 898), 'mouth_right': (502, 898)}}
# {'box': [1041, 812, 31, 40], 'confidence': 0.9999546408653259, 'keypoints': {'left_eye': (1050, 826), 'right_eye': (1065, 827), 'nose': (1057, 833), 'mouth_left': (1050, 842), 'mouth_right': (1062, 844)}}
# {'box': [449, 828, 33, 41], 'confidence': 0.9999373555183411, 'keypoints': {'left_eye': (458, 843), 'right_eye': (474, 842), 'nose': (467, 850), 'mouth_left': (461, 860), 'mouth_right': (474, 859)}}
# {'box': [530, 839, 31, 40], 'confidence': 0.9999268651008606, 'keypoints': {'left_eye': (539, 852), 'right_eye': (555, 854), 'nose': (546, 861), 'mouth_left': (538, 867), 'mouth_right': (552, 869)}}
# {'box': [792, 853, 35, 44], 'confidence': 0.9999213814735413, 'keypoints': {'left_eye': (799, 870), 'right_eye': (816, 869), 'nose': (807, 878), 'mouth_left': (801, 887), 'mouth_right': (815, 886)}}
# {'box': [1250, 1036, 41, 54], 'confidence': 0.9999163746833801, 'keypoints': {'left_eye': (1262, 1057), 'right_eye': (1282, 1057), 'nose': (1272, 1067), 'mouth_left': (1265, 1078), 'mouth_right': (1280, 1078)}}
# {'box': [908, 865, 33, 43], 'confidence': 0.9999127984046936, 'keypoints': {'left_eye': (916, 882), 'right_eye': (932, 882), 'nose': (923, 890), 'mouth_left': (917, 898), 'mouth_right': (931, 898)}}
# {'box': [1179, 860, 37, 47], 'confidence': 0.9999064803123474, 'keypoints': {'left_eye': (1188, 880), 'right_eye': (1205, 878), 'nose': (1196, 889), 'mouth_left': (1191, 897), 'mouth_right': (1205, 896)}}
# {'box': [564, 861, 35, 46], 'confidence': 0.9999021887779236, 'keypoints': {'left_eye': (574, 880), 'right_eye': (591, 880), 'nose': (582, 888), 'mouth_left': (574, 897), 'mouth_right': (590, 897)}}
# {'box': [1603, 829, 40, 49], 'confidence': 0.9998816847801208, 'keypoints': {'left_eye': (1615, 848), 'right_eye': (1634, 847), 'nose': (1626, 857), 'mouth_left': (1617, 866), 'mouth_right': (1635, 865)}}
# {'box': [512, 1073, 41, 49], 'confidence': 0.999879777431488, 'keypoints': {'left_eye': (522, 1092), 'right_eye': (542, 1090), 'nose': (530, 1104), 'mouth_left': (524, 1112), 'mouth_right': (540, 1111)}}
# {'box': [1131, 816, 36, 45], 'confidence': 0.9998142719268799, 'keypoints': {'left_eye': (1139, 833), 'right_eye': (1156, 832), 'nose': (1147, 839), 'mouth_left': (1142, 851), 'mouth_right': (1155, 850)}}
# {'box': [863, 838, 32, 41], 'confidence': 0.9997828006744385, 'keypoints': {'left_eye': (872, 855), 'right_eye': (887, 853), 'nose': (879, 861), 'mouth_left': (874, 871), 'mouth_right': (886, 870)}}
# {'box': [648, 836, 35, 42], 'confidence': 0.9997386932373047, 'keypoints': {'left_eye': (661, 853), 'right_eye': (677, 852), 'nose': (671, 860), 'mouth_left': (662, 868), 'mouth_right': (677, 867)}}
# {'box': [1006, 853, 32, 44], 'confidence': 0.9997107982635498, 'keypoints': {'left_eye': (1015, 871), 'right_eye': (1030, 870), 'nose': (1022, 877), 'mouth_left': (1016, 887), 'mouth_right': (1030, 886)}}
# {'box': [715, 855, 32, 41], 'confidence': 0.9996311068534851, 'keypoints': {'left_eye': (726, 870), 'right_eye': (741, 871), 'nose': (736, 878), 'mouth_left': (728, 887), 'mouth_right': (740, 887)}}
# {'box': [351, 1060, 48, 56], 'confidence': 0.9995805621147156, 'keypoints': {'left_eye': (364, 1086), 'right_eye': (384, 1079), 'nose': (375, 1092), 'mouth_left': (370, 1106), 'mouth_right': (387, 1101)}}
# {'box': [207, 1063, 49, 53], 'confidence': 0.9995023608207703, 'keypoints': {'left_eye': (220, 1083), 'right_eye': (242, 1080), 'nose': (231, 1095), 'mouth_left': (224, 1105), 'mouth_right': (242, 1102)}}
# {'box': [199, 825, 39, 48], 'confidence': 0.9988117814064026, 'keypoints': {'left_eye': (214, 842), 'right_eye': (232, 844), 'nose': (224, 853), 'mouth_left': (213, 861), 'mouth_right': (229, 861)}}
# {'box': [607, 846, 31, 42], 'confidence': 0.9985584616661072, 'keypoints': {'left_eye': (617, 863), 'right_eye': (632, 862), 'nose': (626, 869), 'mouth_left': (619, 879), 'mouth_right': (630, 879)}}
# {'box': [381, 827, 35, 45], 'confidence': 0.9976713061332703, 'keypoints': {'left_eye': (389, 846), 'right_eye': (405, 843), 'nose': (397, 853), 'mouth_left': (392, 863), 'mouth_right': (406, 861)}}
# {'box': [1371, 817, 38, 50], 'confidence': 0.9949329495429993, 'keypoints': {'left_eye': (1380, 838), 'right_eye': (1397, 836), 'nose': (1389, 848), 'mouth_left': (1382, 856), 'mouth_right': (1399, 854)}}

# %%
url='/content/1.jfif'
pixels=plt.imread(url)
detector=MTCNN()
faces=detector.detect_faces(pixels)
for face in faces:
  print(face)
# Out:
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 124ms/step
# WARNING:tensorflow:5 out of the last 17 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fdde491add0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 153ms/step
# {'box': [46, 26, 50, 64], 'confidence': 0.9999995827674866, 'keypoints': {'left_eye': (62, 47), 'right_eye': (84, 55), 'nose': (71, 61), 'mouth_left': (57, 70), 'mouth_right': (76, 76)}}

# %%
url='/content/2.jpg'
pixels=plt.imread(url)
detector=MTCNN()
faces=detector.detect_faces(pixels)
for face in faces:
  print(face)
# Out:
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 4/4 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 142ms/step
# {'box': [139, 116, 99, 127], 'confidence': 0.997611403465271, 'keypoints': {'left_eye': (192, 159), 'right_eye': (224, 171), 'nose': (213, 188), 'mouth_left': (182, 203), 'mouth_right': (207, 214)}}
# {'box': [444, 221, 84, 122], 'confidence': 0.9539850354194641, 'keypoints': {'left_eye': (458, 271), 'right_eye': (494, 270), 'nose': (461, 287), 'mouth_left': (454, 316), 'mouth_right': (478, 316)}}

# %%
#from matplotlib.pyplot as plt
#from mtcnn import MCTNN
url='/content/1.jfif'
pixels=plt.imread(url)
detector=MTCNN()
faces=detector.detect_faces(pixels)
plt.imshow(pixels)
# Out:
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 156ms/step

# %%
anhtest = '/content/1.jpg'
pixels= plt.imread(anhtest)
detector= MTCNN()
face= detector.detect_faces(pixels)
plt.imshow(pixels)
ax= plt.gca()
for face in faces:
  x,y,width,height= face['box']
  rect= plt.Rectangle((x,y),width,height,fill=False,color='red')
  ax.add_patch(rect)
plt.show()
# Out:
# 1/1 [==============================] - 0s 425ms/step
# 1/1 [==============================] - 0s 255ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 51/51 [==============================] - 1s 10ms/step
# 9/9 [==============================] - 1s 42ms/step

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
from keras.utils import load_img,img_to_array
url = '/content/1.jfif'
pixels = plt.imread(url)
detector = MTCNN()
faces = detector.detect_faces(pixels)
data = plt.imshow(pixels)
ax = plt.gca()
for face in faces:
  x, y, width, height = face['box']
  rect = plt.Rectangle((x,y),width,height,
                       fill = False, color= 'blue')
  ax.add_patch(rect)
  for key, value in face['keypoints'].items():
    dot = plt.Circle(value,radius = 2,color = 'red')
    ax.add_patch(dot)
plt.show()
# Out:
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 161ms/step

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN

def draw_faces(filename, result_list):
  data = plt.imread(filename)
  for i in range(len(result_list)):
    x,y,width,height = result_list[i]['box']
    x1,y1 = x + width, y + height
    plt.subplot(1,len(result_list),i+1)
    plt.axis('off')
    plt.imshow(data[y:y1,x:x1])
  plt.show()

filename = '/content/3.jpg'
pixels = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(pixels)
draw_faces(filename,faces)
# Out:
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 302ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 15/15 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 1s 95ms/step

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input
import numpy as np

# %%
model = VGG16(weights='imagenet')

img_path = '5.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)

print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 [==============================] - 1s 686ms/step
# Predicted: [('n03400231', 'frying_pan', 0.9827734), ('n04596742', 'wok', 0.016236002), ('n04270147', 'spatula', 0.00049180066)]

# %%
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg19 import preprocess_input, decode_predictions
import numpy as np

# %%
model = VGG19(weights='imagenet')

img_path = '5.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)

print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 [==============================] - 1s 825ms/step
# Predicted: [('n03400231', 'frying_pan', 0.9475867), ('n04596742', 'wok', 0.05215023), ('n04270147', 'spatula', 0.00019152697)]

# %%
model = VGG16(weights='imagenet')

img_path = '5.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)

print('Predicted:', decode_predictions(preds, top=3)[0])
